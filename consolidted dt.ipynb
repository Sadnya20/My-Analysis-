# %%
import pandas as pd

# %% [markdown]
# ##  Sheet1

# %%
df0 = pd.read_excel('2. Dashboard Data.xlsx', sheet_name='Sheet1', header=None)

# %%
# Initialize containers
name_col = []
category_col = []

# Track current values
cur_customer = None
cur_category = None

# Total rows
n = len(df0)

# Loop safely until the last row (we'll handle it separately if needed)
for i in range(n):
    current_row = df0.iloc[i]

    # Safe default: assume next row is all NaN unless you're on the last row
    next_row_all_nan = True if i == n - 1 else df0.iloc[i + 1].isna().all()

    # Check if only the first column has data
    only_bill_no = pd.notna(current_row[0]) and current_row[1:].isna().all()

    # Apply logic
    if only_bill_no and next_row_all_nan:
        cur_customer = current_row[0]
    elif only_bill_no:
        cur_category = current_row[0]

    name_col.append(cur_customer)
    category_col.append(cur_category)

# Add columns to DataFrame
df0['Customer_Name'] = name_col
df0['Product_Category'] = category_col

# %%
# 🔥 Remove rows where the 3rd column (index 2) contains the word "Total"
df0= df0[~df0[2].astype(str).str.contains('Total', na=False)].reset_index(drop=True)

# %%
df0.columns = ['Bill No', 'Bill Date', 'Product Name', 'R/I', 'Qty', 'Rate', 'Customer_Name', 'Product_Category']

# %%
df0.loc[:29, 'Customer_Name'] = df0.loc[:29, 'Customer_Name'].fillna('A.S.EMBROIDERY')

# %%
df0 = df0.iloc[3:].reset_index(drop=True)

# %%
print(df0.columns.tolist())
# Out:
# ['Bill No', 'Bill Date', 'Product Name', 'R/I', 'Qty', 'Rate', 'Customer_Name', 'Product_Category']

# %%
# Optional: clean column names first
df0.columns = df0.columns.astype(str).str.strip()

# Define the columns to check
cols_to_check = ['Bill Date', 'Product Name', 'R/I', 'Qty', 'Rate']

# Drop rows where all of those columns are NaN
df0 = df0[~df0[cols_to_check].isna().all(axis=1)].reset_index(drop=True)

# %%
if pd.isna(df0.loc[25, 'Customer_Name']):
    df0.loc[25, 'Customer_Name'] = 'A.S.EMBROIDERY'

# %%
print(df0.dtypes)
# Out:
# Bill No             object
# Bill Date           object
# Product Name        object
# R/I                 object
# Qty                 object
# Rate                object
# Customer_Name       object
# Product_Category    object
# dtype: object

# %%
# Convert Bill Date to datetime
df0['Bill Date'] = pd.to_datetime(df0['Bill Date'], errors='coerce')

# Convert numeric columns to numbers
df0['Bill No'] = pd.to_numeric(df0['Bill No'], errors='coerce')
df0['Qty'] = pd.to_numeric(df0['Qty'], errors='coerce')
df0['Rate'] = pd.to_numeric(df0['Rate'], errors='coerce')

# %%
print(df0.dtypes)
# Out:
# Bill No                      int64
# Bill Date           datetime64[ns]
# Product Name                object
# R/I                         object
# Qty                        float64
# Rate                       float64
# Customer_Name               object
# Product_Category            object
# dtype: object

# %%
print(df0.isna().sum())
# Out:
# Bill No             0
# Bill Date           0
# Product Name        0
# R/I                 0
# Qty                 0
# Rate                2
# Customer_Name       0
# Product_Category    0
# dtype: int64

# %%
df0['Customer_Name'] = df0['Customer_Name'].str.rstrip(',').str.strip()

# %%
df0['Rate'] = df0.groupby('Product Name')['Rate'].transform(lambda x: x.fillna(x.mean().round(2)))

# %%
df0.loc[880:900]
# Out:
#      Bill No  Bill Date    Product Name R/I    Qty        Rate  \
# 880     3834 2022-05-16            GVC1   I    1.0  150.000000
# 881     3834 2022-05-16            G627   I    1.0  150.000000
# 882     3834 2022-05-16           G4007   I    1.0  150.000000
# 883     3834 2022-05-16            G304   I    1.0  150.000000
# 884     3834 2022-05-16            G111   I    1.0  150.000000
# 885     5322 2022-06-10           G9718   I    1.0  150.000000
# 886     3834 2022-05-16     G44 1800MTR   I    1.0  150.000000
# 887     3309 2022-05-09           M6050   I    1.0  436.363636
# 888     3309 2022-05-09            M306   I    1.0  420.000000
# 889     3834 2022-05-16            1324   I    1.0  445.000000
# 890     3834 2022-05-16          KM6079   I    1.0  445.000000
# 891     3834 2022-05-16            3202   I    1.0  445.000000
# 892     3834 2022-05-16            3182   I    1.0  445.000000
# 893     1911 2022-04-23  414 JARI 250GM   I  100.0   99.200000
# 894     2111 2022-04-25  414 JARI 250GM   I  100.0   99.200000
# 895     2256 2022-04-26  414 JARI 250GM   I  100.0   99.200000
# 896     2296 2022-04-27  415 JARI 250GM   I  100.0   99.200000
# 897     2701 2022-05-01  414 JARI 250GM   I  100.0   92.000000
# 898     2776 2022-05-02  414 JARI 250GM   I  100.0   92.000000
# 899     2777 2022-05-02  415 JARI 250GM   I  100.0   92.000000
# 900     2891 2022-05-04  415 JARI 250GM   I  200.0   92.000000
#
#       Customer_Name Product_Category
# 880   APOLO RAJBHAI   GERMAN 1200MTR
# 881   APOLO RAJBHAI   GERMAN 1200MTR
# 882   APOLO RAJBHAI   GERMAN 1200MTR
# 883   APOLO RAJBHAI   GERMAN 1200MTR
# 884   APOLO RAJBHAI   GERMAN 1200MTR
# 885   APOLO RAJBHAI   GERMAN 1200MTR
# 886   APOLO RAJBHAI   GERMAN 1800MTR
# 887   APOLO RAJBHAI  VISCOSE 1200MTR
# 888   APOLO RAJBHAI  VISCOSE 1200MTR
# 889   APOLO RAJBHAI  VISCOSE 1200MTR
# 890   APOLO RAJBHAI  VISCOSE 1200MTR
# 891   APOLO RAJBHAI  VISCOSE 1200MTR
# 892   APOLO RAJBHAI  VISCOSE 1200MTR
# 893  ARPIT CREATION      YELLOW JARI
# 894  ARPIT CREATION      YELLOW JARI
# 895  ARPIT CREATION      YELLOW JARI
# 896  ARPIT CREATION      YELLOW JARI
# 897  ARPIT CREATION      YELLOW JARI
# 898  ARPIT CREATION      YELLOW JARI
# 899  ARPIT CREATION      YELLOW JARI
# 900  ARPIT CREATION      YELLOW JARI

# %%
print(df0.isna().sum())
# Out:
# Bill No             0
# Bill Date           0
# Product Name        0
# R/I                 0
# Qty                 0
# Rate                0
# Customer_Name       0
# Product_Category    0
# dtype: int64

# %% [markdown]
# ## sheet 2

# %%
df_1= pd.read_excel('2. Dashboard Data.xlsx', sheet_name='Sheet2', header=None)

# %%
# Initialize containers
name_col = []
category_col = []

# Track current values
cur_customer = None
cur_category = None

# Total rows
n = len(df_1)

# Loop safely until the last row (we'll handle it separately if needed)
for i in range(n):
    current_row = df_1.iloc[i]

    # Safe default: assume next row is all NaN unless you're on the last row
    next_row_all_nan = True if i == n - 1 else df_1.iloc[i + 1].isna().all()

    # Check if only the first column has data
    only_bill_no = pd.notna(current_row[0]) and current_row[1:].isna().all()

    # Apply logic
    if only_bill_no and next_row_all_nan:
        cur_customer = current_row[0]
    elif only_bill_no:
        cur_category = current_row[0]

    name_col.append(cur_customer)
    category_col.append(cur_category)
# Add columns to DataFrame
df_1['Customer_Name'] = name_col
df_1['Product_Category'] = category_col

# %%
# 🔥 Remove rows where the 3rd column (index 2) contains the word "Total"
df_1 = df_1[~df_1[2].astype(str).str.contains('Total', na=False)].reset_index(drop=True)

# %%
df_1.columns = ['Bill No', 'Bill Date', 'Product Name', 'R/I', 'Qty', 'Rate', 'Customer_Name', 'Product_Category']

# %%
df_1.loc[:23, 'Customer_Name'] = df_1.loc[:23, 'Customer_Name'].fillna('A.S.EMBROIDERY')

# %%
df_1 = df_1.iloc[3:].reset_index(drop=True)

# %%
 #Optional: clean column names first
df_1.columns = df_1.columns.astype(str).str.strip()

# Define the columns to check
cols_to_check = ['Bill Date', 'Product Name', 'R/I', 'Qty', 'Rate']

# Drop rows where all of those columns are NaN
df_1 = df_1[~df_1[cols_to_check].isna().all(axis=1)].reset_index(drop=True)

# %%
print(df_1.dtypes)
# Out:
# Bill No             object
# Bill Date           object
# Product Name        object
# R/I                 object
# Qty                 object
# Rate                object
# Customer_Name       object
# Product_Category    object
# dtype: object

# %%
# Convert Bill Date to datetime
df_1['Bill Date'] = pd.to_datetime(df_1['Bill Date'], errors='coerce')

# Convert numeric columns to numbers
df_1['Bill No'] = pd.to_numeric(df_1['Bill No'], errors='coerce')
df_1['Qty'] = pd.to_numeric(df_1['Qty'], errors='coerce')
df_1['Rate'] = pd.to_numeric(df_1['Rate'], errors='coerce')

# %%
print(df_1.dtypes)
# Out:
# Bill No                      int64
# Bill Date           datetime64[ns]
# Product Name                object
# R/I                         object
# Qty                        float64
# Rate                       float64
# Customer_Name               object
# Product_Category            object
# dtype: object

# %%
print(df_1.isna().sum())
# Out:
# Bill No             0
# Bill Date           0
# Product Name        0
# R/I                 0
# Qty                 0
# Rate                0
# Customer_Name       0
# Product_Category    0
# dtype: int64

# %%
pd.set_option('display.max_rows', 400)

# %%
df_1.head(400)
# Out:
#          Bill No            Bill Date        Product Name R/I  Qty  Rate  \
# 0           9694  2022-09-05 00:00:00                6022   I    2   464
# 1           9815  2022-09-07 00:00:00                6022   I    5   464
# 2           9906  2022-09-08 00:00:00                6022   I    5   464
# 3          10051  2022-09-10 00:00:00                6022   I    5   464
# 4          10486  2022-09-16 00:00:00                6022   I    5   464
# 5          10609  2022-09-17 00:00:00                6022   I    5   464
# 6          10810  2022-09-20 00:00:00                6022   I    5   464
# 7          11203  2022-09-24 00:00:00                6022   I    4   464
# 8          11308  2022-09-26 00:00:00                6022   I    6   464
# 9           6244  2022-07-02 00:00:00        J500 3000MTR   I   60    62
# 10          6434  2022-07-08 00:00:00        J500 3000MTR   I   60    62
# 11          7236  2022-07-27 00:00:00        J500 3000MTR   I   30    62
# 12          7254  2022-07-27 00:00:00        J500 3000MTR   I   -4    62
# 13          7815  2022-08-06 00:00:00        J500 3000MTR   I   60    91
# 14          8120  2022-08-10 00:00:00        J500 3000MTR   I   60    91
# 15          8380  2022-08-16 00:00:00        J500 3000MTR   I   45    91
# 16          9031  2022-08-27 00:00:00        J500 3000MTR   I   60    91
# 17         11036  2022-09-22 00:00:00        J500 3000MTR   I   30    91
# 18          8389  2022-08-16 00:00:00                 547   I    3   464
# 19          8389  2022-08-16 00:00:00                6017   I    3   464
# 20          8389  2022-08-16 00:00:00                5059   I    3   464
# 21          8758  2022-08-23 00:00:00                 547   I    3   464
# 22          8758  2022-08-23 00:00:00                6017   I    3   464
# 23          8758  2022-08-23 00:00:00                5059   I    3   464
# 24          9706  2022-09-05 00:00:00                6017   I    4   464
# 25          9706  2022-09-05 00:00:00                5059   I    5   464
# 26          9882  2022-09-07 00:00:00                 547   I    5   464
# 27         10065  2022-09-10 00:00:00                6017   I    3   464
# 28         10065  2022-09-10 00:00:00                5059   I    3   464
# 29         10562  2022-09-16 00:00:00                5059   I    3   464
# 30         10729  2022-09-19 00:00:00                 547   I    5   464
# 31         10729  2022-09-19 00:00:00                6017   I    5   464
# 32         10803  2022-09-19 00:00:00                5059   I    5   464
# 33         11524  2022-09-28 00:00:00                5064   I    3   464
# 34          6221  2022-07-02 00:00:00                5013   I    4   442
# 35          7062  2022-07-23 00:00:00                5013   I    6   442
# 36          7112  2022-07-25 00:00:00                1334   I    5   442
# 37          7112  2022-07-25 00:00:00                 777   I    5   442
# 398        11338  2022-09-26 00:00:00                9077   I   -1   424
# 399        11338  2022-09-26 00:00:00                9008   I   -1   424
#
#          Customer_Name Product_Category
# 0       A.S.EMBROIDERY  VISCOSE 1200MTR
# 1       A.S.EMBROIDERY  VISCOSE 1200MTR
# 2       A.S.EMBROIDERY  VISCOSE 1200MTR
# 3       A.S.EMBROIDERY  VISCOSE 1200MTR
# 4       A.S.EMBROIDERY  VISCOSE 1200MTR
# 5       A.S.EMBROIDERY  VISCOSE 1200MTR
# 6       A.S.EMBROIDERY  VISCOSE 1200MTR
# 7       A.S.EMBROIDERY  VISCOSE 1200MTR
# 8       A.S.EMBROIDERY  VISCOSE 1200MTR
# 9       A.S.EMBROIDERY  VISCOSE 3000MTR
# 10      A.S.EMBROIDERY  VISCOSE 3000MTR
# 11      A.S.EMBROIDERY  VISCOSE 3000MTR
# 12      A.S.EMBROIDERY  VISCOSE 3000MTR
# 13      A.S.EMBROIDERY  VISCOSE 3000MTR
# 14      A.S.EMBROIDERY  VISCOSE 3000MTR
# 15      A.S.EMBROIDERY  VISCOSE 3000MTR
# 16      A.S.EMBROIDERY  VISCOSE 3000MTR
# 17      A.S.EMBROIDERY  VISCOSE 3000MTR
# 18     AADHYA CREATION  VISCOSE 1200MTR
# 19     AADHYA CREATION  VISCOSE 1200MTR
# 20     AADHYA CREATION  VISCOSE 1200MTR
# 21     AADHYA CREATION  VISCOSE 1200MTR
# 22     AADHYA CREATION  VISCOSE 1200MTR
# 23     AADHYA CREATION  VISCOSE 1200MTR
# 24     AADHYA CREATION  VISCOSE 1200MTR
# 25     AADHYA CREATION  VISCOSE 1200MTR
# 26     AADHYA CREATION  VISCOSE 1200MTR
# 27     AADHYA CREATION  VISCOSE 1200MTR
# 28     AADHYA CREATION  VISCOSE 1200MTR
# 29     AADHYA CREATION  VISCOSE 1200MTR
# 30     AADHYA CREATION  VISCOSE 1200MTR
# 31     AADHYA CREATION  VISCOSE 1200MTR
# 32     AADHYA CREATION  VISCOSE 1200MTR
# 33     AADHYA CREATION  VISCOSE 1200MTR
# 34    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 35    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 36    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 37    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 38    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 39    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 40    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 41    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 42    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 43    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 44    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 45    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 46    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 47    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 48    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 49    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 50    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 51    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 52    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 53    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 54    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 55    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 56    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 57    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 58    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 59    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 60    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 61    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 62    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 63    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 64    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 65    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 66    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 67    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 68    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 69    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 70    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 71    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 72    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 73    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 74    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 75    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 76    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 77    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 78    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 79    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 80    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 81    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 82    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 83    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 84    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 85    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 86    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 87    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 88    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 89    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 90    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 91    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 92    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 93    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 94    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 95    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 96    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 97    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 98    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 99    AAGAM ENTERPRISE  VISCOSE 1200MTR
# 100   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 101   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 102   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 103   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 104   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 105   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 106   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 107   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 108   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 109   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 110   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 111   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 112   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 113   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 114   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 115   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 116   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 117   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 118   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 119   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 120   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 121   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 122   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 123   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 124   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 125   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 126   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 127   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 128   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 129   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 130   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 131   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 132   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 133   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 134   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 135   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 136   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 137   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 138   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 139   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 140   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 141   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 142   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 143   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 144   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 145   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 146   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 147   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 148   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 149   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 150   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 151   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 152   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 153   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 154   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 155   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 156   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 157   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 158   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 159   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 160   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 161   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 162   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 163   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 164   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 165   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 166   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 167   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 168   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 169   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 170   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 171   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 172   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 173   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 174   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 175   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 176   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 177   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 178   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 179   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 180   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 181   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 182   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 183   AAGAM ENTERPRISE  VISCOSE 1200MTR
# 184   AAGAM ENTERPRISE       WHITE JARI
# 185   AAGAM ENTERPRISE       WHITE JARI
# 186   AAGAM ENTERPRISE       WHITE JARI
# 187   AAGAM ENTERPRISE       WHITE JARI
# 188   AAGAM ENTERPRISE      YELLOW JARI
# 189   AAGAM ENTERPRISE      YELLOW JARI
# 190     AARCHI FASHION   GERMAN 1200MTR
# 191     AARCHI FASHION   GERMAN 1200MTR
# 192     AARCHI FASHION   GERMAN 1200MTR
# 193     AARCHI FASHION   GERMAN 1200MTR
# 194     AARCHI FASHION   GERMAN 1200MTR
# 195     AARCHI FASHION   GERMAN 1200MTR
# 196     AARCHI FASHION   GERMAN 1200MTR
# 197     AARCHI FASHION   GERMAN 1200MTR
# 198     AARCHI FASHION   GERMAN 1200MTR
# 199     AARCHI FASHION   GERMAN 1200MTR
# 200     AARCHI FASHION   GERMAN 1200MTR
# 201     AARCHI FASHION   GERMAN 1200MTR
# 202     AARCHI FASHION   GERMAN 1200MTR
# 203     AARCHI FASHION   GERMAN 1200MTR
# 204     AARCHI FASHION   GERMAN 1200MTR
# 205     AARCHI FASHION   GERMAN 1200MTR
# 206     AARCHI FASHION   GERMAN 1200MTR
# 207     AARCHI FASHION   GERMAN 1200MTR
# 208     AARCHI FASHION   GERMAN 1200MTR
# 209     AARCHI FASHION   GERMAN 1200MTR
# 210     AARCHI FASHION   GERMAN 1200MTR
# 211     AARCHI FASHION   GERMAN 1200MTR
# 212     AARCHI FASHION   GERMAN 1200MTR
# 213     AARCHI FASHION   GERMAN 1200MTR
# 214     AARCHI FASHION   GERMAN 1200MTR
# 215     AARCHI FASHION   GERMAN 1200MTR
# 216     AARCHI FASHION   GERMAN 1200MTR
# 217     AARCHI FASHION   GERMAN 1200MTR
# 218     AARCHI FASHION   GERMAN 1800MTR
# 219     AARCHI FASHION   GERMAN 1800MTR
# 220     AARCHI FASHION   GERMAN 1800MTR
# 221     AARCHI FASHION   GERMAN 1800MTR
# 222     AARCHI FASHION   GERMAN 1800MTR
# 223     AARCHI FASHION  VISCOSE 1200MTR
# 224     AARCHI FASHION  VISCOSE 1200MTR
# 225     AARCHI FASHION  VISCOSE 1200MTR
# 226     AARCHI FASHION  VISCOSE 1200MTR
# 227     AARCHI FASHION  VISCOSE 1200MTR
# 228     AARCHI FASHION  VISCOSE 1200MTR
# 229     AARCHI FASHION  VISCOSE 1200MTR
# 230     AARCHI FASHION  VISCOSE 1200MTR
# 231     AARCHI FASHION  VISCOSE 1200MTR
# 232     AARCHI FASHION  VISCOSE 1200MTR
# 233     AARCHI FASHION  VISCOSE 1200MTR
# 234     AARCHI FASHION  VISCOSE 1200MTR
# 235     AARCHI FASHION  VISCOSE 1200MTR
# 236     AARCHI FASHION  VISCOSE 1200MTR
# 237     AARCHI FASHION  VISCOSE 1200MTR
# 238     AARCHI FASHION  VISCOSE 1200MTR
# 239     AARCHI FASHION  VISCOSE 1200MTR
# 240     AARCHI FASHION  VISCOSE 1200MTR
# 241     AARCHI FASHION  VISCOSE 1200MTR
# 242     AARCHI FASHION  VISCOSE 1200MTR
# 243     AARCHI FASHION  VISCOSE 1200MTR
# 244     AARCHI FASHION  VISCOSE 1200MTR
# 245     AARCHI FASHION  VISCOSE 1200MTR
# 246     AARCHI FASHION  VISCOSE 1200MTR
# 247     AARCHI FASHION  VISCOSE 1200MTR
# 248     AARCHI FASHION  VISCOSE 1200MTR
# 249     AARCHI FASHION  VISCOSE 1200MTR
# 250     AARCHI FASHION  VISCOSE 1200MTR
# 251     AARCHI FASHION  VISCOSE 1200MTR
# 252     AARCHI FASHION  VISCOSE 1200MTR
# 253     AARCHI FASHION  VISCOSE 1200MTR
# 254     AARCHI FASHION  VISCOSE 1200MTR
# 255     AARCHI FASHION  VISCOSE 1200MTR
# 256     AARCHI FASHION  VISCOSE 1200MTR
# 257     AARCHI FASHION  VISCOSE 1200MTR
# 258     AARCHI FASHION  VISCOSE 1200MTR
# 259     AARCHI FASHION  VISCOSE 1200MTR
# 260     AARCHI FASHION  VISCOSE 1200MTR
# 261     AARCHI FASHION  VISCOSE 1200MTR
# 262     AARCHI FASHION  VISCOSE 1200MTR
# 263     AARCHI FASHION  VISCOSE 1200MTR
# 264     AARCHI FASHION  VISCOSE 1200MTR
# 265     AARCHI FASHION  VISCOSE 1200MTR
# 266     AARCHI FASHION  VISCOSE 1200MTR
# 267     AARCHI FASHION  VISCOSE 1200MTR
# 268     AARCHI FASHION  VISCOSE 1200MTR
# 269     AARCHI FASHION  VISCOSE 1200MTR
# 270     AARCHI FASHION  VISCOSE 1200MTR
# 271     AARCHI FASHION  VISCOSE 1200MTR
# 272     AARCHI FASHION  VISCOSE 1200MTR
# 273     AARCHI FASHION  VISCOSE 1200MTR
# 274     AARCHI FASHION  VISCOSE 1200MTR
# 275     AARCHI FASHION  VISCOSE 1200MTR
# 276     AARCHI FASHION  VISCOSE 1200MTR
# 277     AARCHI FASHION  VISCOSE 1200MTR
# 278     AARCHI FASHION  VISCOSE 1200MTR
# 279     AARCHI FASHION  VISCOSE 1200MTR
# 280     AARCHI FASHION  VISCOSE 1200MTR
# 281     AARCHI FASHION  VISCOSE 1200MTR
# 282     AARCHI FASHION  VISCOSE 1200MTR
# 283     AARCHI FASHION  VISCOSE 1200MTR
# 284     AARCHI FASHION  VISCOSE 1200MTR
# 285     AARCHI FASHION  VISCOSE 1200MTR
# 286     AARCHI FASHION  VISCOSE 1200MTR
# 287     AARCHI FASHION  VISCOSE 1200MTR
# 288     AARCHI FASHION  VISCOSE 1200MTR
# 289     AARCHI FASHION  VISCOSE 1200MTR
# 290     AARCHI FASHION  VISCOSE 1200MTR
# 291     AARCHI FASHION  VISCOSE 1200MTR
# 292     AARCHI FASHION  VISCOSE 1200MTR
# 293     AARCHI FASHION  VISCOSE 1200MTR
# 294     AARCHI FASHION  VISCOSE 1200MTR
# 354     AARCHI FASHION       WHITE JARI
# 355     AARCHI FASHION       WHITE JARI
# 356     AARCHI FASHION       WHITE JARI
# 357     AARCHI FASHION      YELLOW JARI
# 358     AARCHI FASHION      YELLOW JARI
# 359  AASTHA ENTERPRISE   GERMAN 1200MTR
# 360  AASTHA ENTERPRISE   GERMAN 1200MTR
# 361  AASTHA ENTERPRISE   GERMAN 1200MTR
# 362  AASTHA ENTERPRISE   GERMAN 1200MTR
# 363  AASTHA ENTERPRISE   GERMAN 1200MTR
# 364  AASTHA ENTERPRISE   GERMAN 1200MTR
# 365  AASTHA ENTERPRISE   GERMAN 1200MTR
# 366  AASTHA ENTERPRISE   GERMAN 1200MTR
# 367  AASTHA ENTERPRISE   GERMAN 1200MTR
# 368  AASTHA ENTERPRISE   GERMAN 1200MTR
# 369  AASTHA ENTERPRISE   GERMAN 1200MTR
# 370  AASTHA ENTERPRISE   GERMAN 1200MTR
# 371  AASTHA ENTERPRISE   GERMAN 1200MTR
# 372  AASTHA ENTERPRISE   GERMAN 1200MTR
# 373  AASTHA ENTERPRISE   GERMAN 1200MTR
# 374  AASTHA ENTERPRISE   GERMAN 1200MTR
# 375  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 376  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 377  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 378  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 379  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 380  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 381  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 382  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 383  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 384  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 385  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 386  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 387  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 388  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 389  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 390  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 391  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 392  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 393  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 394  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 395  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 396  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 397  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 398  AASTHA ENTERPRISE  VISCOSE 1200MTR
# 399  AASTHA ENTERPRISE  VISCOSE 1200MTR

# %% [markdown]
# ## sheet 3

# %%
df2 = pd.read_excel('2. Dashboard Data.xlsx', sheet_name='Sheet3', header=None)

# %%
# Initialize containers
name_col = []
category_col = []

# Track current values
cur_customer = None
cur_category = None

# Total rows
n = len(df2)

# Loop safely until the last row (we'll handle it separately if needed)
for i in range(n):
    current_row = df2.iloc[i]

    # Safe default: assume next row is all NaN unless you're on the last row
    next_row_all_nan = True if i == n - 1 else df2.iloc[i + 1].isna().all()

    # Check if only the first column has data
    only_bill_no = pd.notna(current_row[0]) and current_row[1:].isna().all()

    # Apply logic
    if only_bill_no and next_row_all_nan:
        cur_customer = current_row[0]
    elif only_bill_no:
        cur_category = current_row[0]

    name_col.append(cur_customer)
    category_col.append(cur_category)
# Add columns to DataFrame
df2['Customer_Name'] = name_col
df2['Product_Category'] = category_col

# %%
# 🔥 Remove rows where the 3rd column (index 2) contains the word "Total"
df2 = df2[~df2[2].astype(str).str.contains('Total', na=False)].reset_index(drop=True)

# %% [markdown]
# ## sheet 4

# %%
df3 = pd.read_excel('2. Dashboard Data.xlsx', sheet_name='Sheet4', header=None)

# %%
# Initialize containers
name_col = []
category_col = []

# Track current values
cur_customer = None
cur_category = None

# Total rows
n = len(df3)

# Loop safely until the last row (we'll handle it separately if needed)
for i in range(n):
    current_row = df3.iloc[i]

    # Safe default: assume next row is all NaN unless you're on the last row
    next_row_all_nan = True if i == n - 1 else df3.iloc[i + 1].isna().all()

    # Check if only the first column has data
    only_bill_no = pd.notna(current_row[0]) and current_row[1:].isna().all()

    # Apply logic
    if only_bill_no and next_row_all_nan:
        cur_customer = current_row[0]
    elif only_bill_no:
        cur_category = current_row[0]

    name_col.append(cur_customer)
    category_col.append(cur_category)
# Add columns to DataFrame
df3['Customer_Name'] = name_col
df3['Product_Category'] = category_col

# %%
# 🔥 Remove rows where the 3rd column (index 2) contains the word "Total"
df3 = df3[~df3[2].astype(str).str.contains('Total', na=False)].reset_index(drop=True)

# %% [markdown]
# ## sheet 5

# %%
df4 = pd.read_excel('2. Dashboard Data.xlsx', sheet_name='Sheet5', header=None)

# %%
# Initialize containers
name_col = []
category_col = []

# Track current values
cur_customer = None
cur_category = None

# Total rows
n = len(df4)

# Loop safely until the last row (we'll handle it separately if needed)
for i in range(n):
    current_row = df4.iloc[i]

    # Safe default: assume next row is all NaN unless you're on the last row
    next_row_all_nan = True if i == n - 1 else df4.iloc[i + 1].isna().all()

    # Check if only the first column has data
    only_bill_no = pd.notna(current_row[0]) and current_row[1:].isna().all()

    # Apply logic
    if only_bill_no and next_row_all_nan:
        cur_customer = current_row[0]
    elif only_bill_no:
        cur_category = current_row[0]

    name_col.append(cur_customer)
    category_col.append(cur_category)
# Add columns to DataFrame
df4['Customer_Name'] = name_col
df4['Product_Category'] = category_col
# 🔥 Remove rows where the 3rd column (index 2) contains the word "Total"
df4 = df4[~df4[2].astype(str).str.contains('Total', na=False)].reset_index(drop=True)

# %%
## sheet 6

# %%
df5 = pd.read_excel('2. Dashboard Data.xlsx', sheet_name='Sheet6', header=None)

# %%
# Initialize containers
name_col = []
category_col = []

# Track current values
cur_customer = None
cur_category = None

# Total rows
n = len(df5)

# Loop safely until the last row (we'll handle it separately if needed)
for i in range(n):
    current_row = df5.iloc[i]

    # Safe default: assume next row is all NaN unless you're on the last row
    next_row_all_nan = True if i == n - 1 else df5.iloc[i + 1].isna().all()

    # Check if only the first column has data
    only_bill_no = pd.notna(current_row[0]) and current_row[1:].isna().all()

    # Apply logic
    if only_bill_no and next_row_all_nan:
        cur_customer = current_row[0]
    elif only_bill_no:
        cur_category = current_row[0]

    name_col.append(cur_customer)
    category_col.append(cur_category)
# Add columns to DataFrame
df5['Customer_Name'] = name_col
df5['Product_Category'] = category_col
# 🔥 Remove rows where the 3rd column (index 2) contains the word "Total"
df5 = df5[~df5[2].astype(str).str.contains('Total', na=False)].reset_index(drop=True)
